# %%
-- =========================================
-- GOLD (vistas si luego creas para Power BI)
-- =========================================

DROP VIEW IF EXISTS catalog_smartdata.gold.vw_powerbi_autos;

DROP TABLE IF EXISTS catalog_smartdata.gold.fact_autos;

DROP TABLE IF EXISTS catalog_smartdata.gold.dim_drive;
DROP TABLE IF EXISTS catalog_smartdata.gold.dim_fuel;
DROP TABLE IF EXISTS catalog_smartdata.gold.dim_engine;
DROP TABLE IF EXISTS catalog_smartdata.gold.dim_body_style;
DROP TABLE IF EXISTS catalog_smartdata.gold.dim_make;
DROP TABLE IF EXISTS catalog_smartdata.silver.autos_conformed;
DROP TABLE IF EXISTS catalog_smartdata.silver.vehicle_specs;
DROP TABLE IF EXISTS catalog_smartdata.silver.engine_specs;
DROP TABLE IF EXISTS catalog_smartdata.silver.autos_clean;

DROP TABLE IF EXISTS catalog_smartdata.bronze.automobile;
